# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 자료형이 딕셔너리의 경우 키값으로 찾기 ex. json_meta = json_cor.get('metadata')
# 자료형이 리스트+딕셔너리일 경우 우선 리스트 index 값으로 접근 후 키값 입력 ex. title = json_docu[0]['metadata']['title']

# %%
#https://www.python2.net/questions-198850.htm
import os
import json
folderpath = r"/content/drive/MyDrive/분석말뭉치_문서단위" # make sure to put the 'r' in front
filepaths  = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]
all_files = []
for path in filepaths:
    with open(path, 'r') as json_file:
         #읽은 파일을 제이슨 형식으로 형변환
        json_cor = json.load(json_file)
         #제이슨 내부의 데이터 리스트 get
########################################
        json_id =  json_cor.get('id')
        '''
        {
            "id": "SBSC2102112200",
            "metadata": { 가 불러와짐
        '''
########################################
        json_meta = json_cor.get('metadata')
        '''
        "metadata": {
            "title": "국립국어원 국회 회의록 요약 분석 말뭉치 SBSC2102112200",
            "creator": "국립국어원",
            "distributor": "국립국어원",
            "year": "2021",
            "category": "회의록 > 국회소위원회",
            "annotation_level": "요약 분석",
            "sampling": "본문 전체"
         }, 가 불러와짐
        '''
########################################
        json_docu = json_cor.get('document')
        '''
        {
        "id": "SBSC2102112200",
        "metadata": {
            "title": "국립국어원 국회 회의록 요약 분석 ..."
        },
        "document": [
        {
            "id": "SBRW2100000048.1",
            "metadata": {
                "title": "제311회국회(정기..... 가 list로 반환됨
        '''
########################################
        id = json_docu[0]['id']
        title = json_docu[0]['metadata']['title']
        sentence = json_docu[0]['sentence']
        sent_id = sentence[0]['id']
        sent_form = sentence[0]['form']
        #json_docu는 document = [...]라는 리스트
        #이 document 리스트는 모든 내용이 리스트에 딕셔너리로 저장된 형태이므로 인덱스가 0밖에 없음

        #sentence = json_docu[0]['sentence']['id']
        print(sent_id+': '+sent_form)

########################################
        
        f = open('/content/drive/MyDrive/4차납품.txt', mode ='a', encoding='utf-8')
        for i in range (len(json_docu)):
            id = json_docu[i]['id']
            title = json_docu[i]['metadata']['title']
            sentence = json_docu[i]['sentence']
            for j in range(len(sentence)):
                sent_id = sentence[j]['id']
                sent_form = sentence[j]['form']
                #print(id+':'+title+'\n'+sent_id+'\t'+sent_form)
                f.write('\t'+id+':'+title+'\n'+sent_id+':'+sent_form)
        f.close()
# Out:
# SBRW2100000092.1.1.1: 성원이 되었으므로 제329회 국회(정기회) 국방위원회 제1차 예산결산심사소위원회를 개의하겠습니다.
# SBRW2100000086.1.1.1: 성원이 되었으므로 제326회 국회 국방위원회 제1차 법률안심사소위원회를 개의합니다.
# SBRW2100000099.1.1.1: 좌석을 정돈하여 주시기 바랍니다.
# SBRW2100000124.1.1.1: 좌석을 정돈해 주시기 바랍니다.
# SBRW2100000166.1.1.1: 의석을 정돈하여 주시기 바랍니다.
# SBRW2100000200.1.1.1: 의석을 정돈해 주시기 바랍니다.
# SBRW2100000062.1.1.1: 시간이 됐는데요, 자리 좀 정돈해 주시고요.
# SBRW2100000108.1.1.1: 좌석을 정돈해 주시기 바랍니다.
# SBRW2100000095.1.1.1: 의석을 정돈하여 주시기 바랍니다.
# SBRW2100000170.1.1.1: 의석을 정돈해 주시기 바랍니다.
# SBRW2100000051.1.1.1: 성원이 되었으므로 제315회 국회(임시회) 국방위원회 제1차 예산결산심사소위원회를 개의하겠습니다.
# SBRW2100000056.1.1.1: 좌석을 정돈해 주시기 바랍니다.
# SBRW2100000064.1.1.1: 의석을 정돈해 주시기 바랍니다.
# SBRW2100000082.1.1.1: 좌석을 정돈해 주시기 바랍니다.
# SBRW2100000054.1.1.1: 의석을 정돈해 주시기 바랍니다.
# SBRW2100000105.1.1.1: 의석을 정돈하여 주시기 바랍니다.
# SBRW2100000126.1.1.1: 성원이 되었으므로 제346회 국회(정기회) 기획재정위원회 제2차 예산결산기금심사소위원회를 개의하겠습니다.
# SBRW2100000127.1.1.1: 의석을 정돈해 주시기 바랍니다.
# SBRW2100000148.1.1.1: 의석을 정돈해 주시기 바랍니다.
# SBRW2100000149.1.1.1: 성원이 되었으므로 363회 국회(임시회) 법제사법위원회 제1차 법안심사제1소위원회 회의를 개의하겠습니다.
# SBRW2100000101.1.1.1: 성원이 되었으므로 제332회 국회(임시회) 제3차 법안심사제1소위원회를 개의합니다.
# SBRW2100000129.1.1.1: 성원이 되었으므로 제348회 국회(임시회) 제1차 법안심사제1소위원회를 개최합니다.
# SBRW2100000113.1.1.1: 성원이 되었으므로 제335회 국회(임시회) 제1차 법안심사제2소위원회를 개의하겠습니다.
# SBRW2100000154.1.1.1: 의석을 정돈하여 주시기 바랍니다.
# SBRW2100000046.1.1.1: 회의 진행하겠습니다.
# SBRW2100000117.1.1.1: 좌석을 정돈해 주시기 바랍니다.
# SBRW2100000186.1.1.1: 의석을 정돈하여 주시기 바랍니다.
# SBRW2100000118.1.1.1: 좌석을 정돈해 주시기 바랍니다.
# SBRW2100000128.1.1.1: 성원이 되었으므로 제346회 국회(정기회) 보건복지위원회 제4차 예산결산심사소위원회를 개의하겠습니다.
# SBRW2100000111.1.1.1: 의석을 정돈해 주시기 바랍니다.
# SBRW2100000150.1.1.1: 좌석을 정돈해 주시기 바랍니다.
# SBRW2100000110.1.1.1: 좌석을 정돈해 주시기 바랍니다.
# SBRW2100000139.1.1.1: 의석을 정돈해 주시기 바랍니다.
# SBRW2100000155.1.1.1: 의석을 정돈하여 주시기 바랍니다.
# SBRW2100000047.1.1.1: 좌석을 정돈해 주시기 바랍니다.
# SBRW2100000199.1.1.1: 좌석을 정돈해 주시기 바랍니다.
# SBRW2100000106.1.1.1: 그러면 회의 시작하도록 하겠습니다.
# SBRW2100000182.1.1.1: 위원님들, 의석을 정돈해 주시기 바랍니다.
# SBRW2100000146.1.1.1: 의석을 정돈해 주시기 바랍니다.
# SBRW2100000175.1.1.1: 의석을 정돈하여 주시기 바랍니다.
# SBRW2100000188.1.1.1: 의석을 정돈해 주시기 바랍니다.
# SBRW2100000085.1.1.1: 의석을 정돈해 주시기 바랍니다.
# SBRW2100000131.1.1.1: 의석을 정돈해 주시기 바랍니다.
# SBRW2100000091.1.1.1: 의석을 정돈해 주시고요.
# SBRW2100000169.1.1.1: 의석을 정돈해 주시기 바랍니다.
# SBRW2100000142.1.1.1: 의석을 정돈해 주시기 바랍니다.

# %%
###########json 낱장 파싱 코드 #############

#파일 읽어오기
with open('/content/drive/MyDrive/잠시실험/SXLS1902008030.json', 'r') as json_file:
    #읽은 파일을 제이슨 형식으로 형변환
    json_cor = json.load(json_file)
    json_document = json_cor.get('sentence')
    #제이슨 내부의 데이터 리스트 get

    #json_paragraph = json_document.get('paragraph')

#print(json_document)
# Out:
# 544

# %%
# 연습용
#https://www.python2.net/questions-198850.htm
import os
import json
folderpath = r"/content/drive/MyDrive/분석말뭉치_문서단위" # make sure to put the 'r' in front
filepaths  = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]
all_files = []
for path in filepaths:
    with open(path, 'r') as json_file:
         #읽은 파일을 제이슨 형식으로 형변환
        json_cor = json.load(json_file)
         #제이슨 내부의 데이터 리스트 get
        json_meta = json_cor.get('metadata')
        json_docu = json_cor.get('document')
        utter = json_docu['utterance']
        #id = json_docu['id']
       #json_paragraph = json_document.get('paragraph')
       #get한 데이터 리스트 내부에 있는 딕셔너리 꺼내오기
        #for document in json_document:
            #json_paragraph = document.get('original_form')
            #print(json_paragraph) #08번 제이슨부터 13번 제이슨의 paragraph가 다 따짐
        print(utter)
        f = open('/content/drive/MyDrive/2차납품.txt', mode ='a', encoding='utf-8')
        for i in range (len(utter)):
            id = utter[i]['id']
            forms = utter[i]['form']
            speaker_id = utter[i]['speaker_id']
            f.write(id+'\t'+speaker_id+'\t'+forms+'\n')
        f.close()

#SBRW2100000003 문제: 0kb일 경우 파싱 안됨

# %%
# 연습용2
#https://www.python2.net/questions-198850.htm
import os
import json
folderpath = r"/content/drive/MyDrive/분석말뭉치_문서단위" # make sure to put the 'r' in front
filepaths  = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]
all_files = []
for path in filepaths:
    with open(path, 'r') as json_file:
         #읽은 파일을 제이슨 형식으로 형변환
        json_cor = json.load(json_file)
         #제이슨 내부의 데이터 리스트 get
        #json_meta = json_cor.get('metadata')
        json_docu = json_cor.get('document')
        utterid = json_docu[0]['sentence'][1]['id']
        utter = json_docu[0]['sentence'][1]['form']
        utters = json_docu[0]['sentence']
        print(utterid+utter)

       #get한 데이터 리스트 내부에 있는 딕셔너리 꺼내오기
        #for document in json_document:
            #json_paragraph = document.get('original_form')
            #print(json_paragraph) #08번 제이슨부터 13번 제이슨의 paragraph가 다 따짐

        f = open('/content/drive/MyDrive/2차a납품.txt', mode ='a', encoding='utf-8')

        for i in range (len(utters)):
            id = utters[i]['id']
            forms = utters[i]['form']
            #speaker_id = utter[i]['speaker_id']
            f.write(id+'\t'+forms+'\n')
        f.close() # 이거 위치 잘 정해야 전체 내용이 적힘 이야....

#SBRW2100000003 문제: 0kb일 경우 파싱 안됨

# %%
# 연습용3
#https://www.python2.net/questions-198850.htm
import os
import json
folderpath = r"/content/drive/MyDrive/분석말뭉치_문서단위" # make sure to put the 'r' in front
filepaths  = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]
all_files = []
for path in filepaths:
    with open(path, 'r') as json_file:
         #읽은 파일을 제이슨 형식으로 형변환
        json_cor = json.load(json_file)
         #제이슨 내부의 데이터 리스트 get
        #json_meta = json_cor.get('metadata')
        json_docu = json_cor.get('header')
        print(json_docu)
        #utterid = json_docu[0]['sentence'][1]['id']
        #utter = json_docu[0]['sentence'][1]['form']
        #utters = json_docu[0]['sentence']
        #print(utterid+utter)

       #get한 데이터 리스트 내부에 있는 딕셔너리 꺼내오기
        #for document in json_document:
            #json_paragraph = document.get('original_form')
            #print(json_paragraph) #08번 제이슨부터 13번 제이슨의 paragraph가 다 따짐
# Out:
# None
